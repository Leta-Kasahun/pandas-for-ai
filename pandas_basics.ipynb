# %% [markdown]
# <h2 style="font-family: sans-serif;">pandas Series</h2>
#
# <p style="font-family: sans-serif; ">
# A <strong>pandas Series</strong> is a 1-dimensional labeled array that can hold numbers, text, or Python objects.
# Think of it as a <em>single column in a spreadsheet</em> with an <strong>index</strong>.
# Each column in a DataFrame is a Series and is essential for AI data preparation.
# </p>
#
# <ul style="font-family: sans-serif;  line-height:1.5;">
#   <li><strong>Index:</strong> Labels each element for easy selection and alignment.</li>
#   <li><strong>Vectorized Operations:</strong> Apply arithmetic or logical operations to all elements at once.</li>
#   <li><strong>Data Types:</strong> Supports numeric, categorical, and text — useful for ML features.</li>
#   <li><strong>NumPy Integration:</strong> Most Series operations use NumPy under the hood for efficiency.</li>
#   <li><strong>Selection & Filtering:</strong> Access elements by label or position, or filter by conditions.</li>
#   <li><strong>Missing Data:</strong> NaN values are handled naturally — important for cleaning datasets.</li>
# </ul>

# %%
import pandas as pd
data=[100,200,300,400]
series=pd.Series(data)
print(series)

calories={"day 1":1990,"day 2":2009,"day 3":4390,"day 4":1320}
series1=pd.Series(calories)
series1["day 2"]+=989
series1["day 5"]=455
print(series1)
print(series1.loc["day 1"])
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# day 1    1990
# day 2    2998
# day 3    4390
# day 4    1320
# day 5     455
# dtype: int64
# 1990

# %% [markdown]
# <h2>Introducing DataFrames</h2>
#
# <p>
# DataFrames are 2-dimensional labeled structures in pandas — like tables in a spreadsheet.
# Mastering them is essential for AI and machine learning workflows. Key manipulations include inspecting data, sorting, subsetting, and adding new columns.
# </p>
#
# <ul>
#   <li><strong>Introducing DataFrames:</strong> Understand the structure of rows, columns, and indices.</li>
#   <li><strong>Inspecting a DataFrame:</strong> Use <code>.head()</code>, <code>.tail()</code>, <code>.info()</code>, and <code>.describe()</code> to explore data.</li>
#   <li><strong>Parts of a DataFrame:</strong> Columns (Series), index (row labels), and underlying data.</li>
#   <li><strong>Sorting Rows:</strong> Sort by values or index using <code>.sort_values()</code> and <code>.sort_index()</code>.</li>
#   <li><strong>Subsetting Columns:</strong> Select one or more columns using <code>df['col']</code> or <code>df[['col1','col2']]</code>.</li>
#   <li><strong>Subsetting Rows:</strong> Filter rows by conditions, positions, or categorical variables.</li>
#   <li><strong>Adding New Columns:</strong> Create new columns by assignment, calculations, or applying functions.</li>
#   <li><strong>Combo-Attack:</strong> Combine multiple manipulations to explore and clean real-world datasets efficiently.</li>
# </ul>

# %%
import pandas as pd
data = {
    "Day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"],
    "Steps": [7000, 8500, 9000, 10000, 7500],
    "Calories": [2200, 2100, 2300, 2500, 2000]
}

df=pd.DataFrame(data)
print(df)
print("selecting only one column")
print(df["Steps"])
print("displaying where the steep is above 8000")
print(df[df["Steps"]>8000])
# Out:
#          Day  Steps  Calories
# 0     Monday   7000      2200
# 1    Tuesday   8500      2100
# 2  Wednesday   9000      2300
# 3   Thursday  10000      2500
# 4     Friday   7500      2000
# selecting only one column
# 0     7000
# 1     8500
# 2     9000
# 3    10000
# 4     7500
# Name: Steps, dtype: int64
# displaying where the steep is above 8000
#          Day  Steps  Calories
# 1    Tuesday   8500      2100
# 2  Wednesday   9000      2300
# 3   Thursday  10000      2500

# %% [markdown]
# <h2>Step 2: Inspecting a DataFrame<h2>
# <h5>Why Inspect a DataFrame?
#
# To understand your data before processing
#
# Check number of rows/columns, data types, missing values, and basic stats<h5>

# %%
#inspecting dataframe  to understund the data  before  performing opration  on the  dataframe
print("Instpecting using .head() to return  the first 5 rows")
#to show these we have to upadst to adds two rows
new_row=pd.DataFrame({
    "Day":["Saturday","Sunday"],
    "Steps":[8500,6780],
    "Calories":[2440,2123]
})
#concatnating them 
df=pd.concat([df,new_row],ignore_index=True)

print(df.head())

print("Inspecting using .tail()  to get the last 5 rows")
print(df.tail())
print("checking  the structure and info using .info()")
print(df.info())
print("showint the  summery stats for the numerical cols")
print(df.describe())
# Out:
# Instpecting using .head() to return  the first 5 rows
#     Day_name  Step_count  Cal_burned  Day  Steps  Calories
# 0     Monday      7000.0      2200.0  NaN    NaN       NaN
# 1    Tuesday      8500.0      2100.0  NaN    NaN       NaN
# 2  Wednesday      9000.0      2300.0  NaN    NaN       NaN
# 3   Thursday     10000.0      2500.0  NaN    NaN       NaN
# 4     Friday      7500.0      2000.0  NaN    NaN       NaN
# Inspecting using .tail()  to get the last 5 rows
#    Day_name  Step_count  Cal_burned       Day   Steps  Calories
# 4    Friday      7500.0      2000.0       NaN     NaN       NaN
# 5  Saturday      8500.0      2440.0       NaN     NaN       NaN
# 6    Sunday      6780.0      2123.0       NaN     NaN       NaN
# 7       NaN         NaN         NaN  Saturday  8500.0    2440.0
# 8       NaN         NaN         NaN    Sunday  6780.0    2123.0
# checking  the structure and info using .info()
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# ...

# %% [markdown]
# <h2>Step 3: DataFrame Parts</h2>
#
# <h5>A pandas DataFrame has key components that define its structure and are essential for data inspection, manipulation, and AI preprocessing.</h5>
#
# <ul>
#   <li><strong>.index</strong> – Row labels of the DataFrame. Allows row selection, alignment, and time series labeling.</li>
#   <li><strong>.columns</strong> – Column labels of the DataFrame. Enables feature selection, renaming, and descriptive datasets.</li>
#   <li><strong>.values</strong> – The underlying NumPy array of data. Needed for fast computations and ML model input.</li>
#   <li><strong>.shape</strong> – Tuple of (rows, columns). Quickly understand dataset size for processing.</li>
#   <li><strong>.dtypes</strong> – Data type of each column. Ensures correct numeric/categorical handling for analysis or AI.</li>
#   <li><strong>.T</strong> – Transpose of the DataFrame (swap rows & columns). Provides alternative view and helps in mathematical operations.</li>
# </ul>

# %%
print(df.columns)
df.columns=["Day_name","Step_count","Cal_burned"]
print("after column is renamed")
print(df.columns)
print("only values")
print(df.values)
print("only index")
print()
print(df.index)
df.index=[1,2,3,4,5,6,7]
print("After updating the index",df.index)
print("Undestanding clo and row quickly uning .shape",df.shape)
print("datatype ",df.dtypes)
# Out:
# Index(['Day_name', 'Step_count', 'Cal_burned'], dtype='str')
# after column is renamed
# Index(['Day_name', 'Step_count', 'Cal_burned'], dtype='str')
# only values
# [['Monday' 7000 2200]
#  ['Tuesday' 8500 2100]
#  ['Wednesday' 9000 2300]
#  ['Thursday' 10000 2500]
#  ['Friday' 7500 2000]
#  ['Saturday' 8500 2440]
#  ['Sunday' 6780 2123]]
# only index
#
# Index([1, 2, 3, 4, 5, 6, 7], dtype='int64')
# After updating the index Index([1, 2, 3, 4, 5, 6, 7], dtype='int64')
# Undestanding clo and row quickly uning .shape (7, 3)
# datatype  Day_name        str
# Step_count    int64
# Cal_burned    int64
# dtype: object

# %% [markdown]
# <h2>Step 4: Sorting and Subsetting DataFrames</h2>
#
# <h5>
# Sorting is used to arrange data in ascending or descending order based on column values.
# It helps find highest, lowest, or chronological patterns in the dataset.
# </h5>
#
# <h5>
# Subsetting is used to select specific rows or columns from a DataFrame.
# It allows you to focus only on relevant data for analysis or model training.
# </h5>
#
# <ul>
#   <li><strong>Sorting</strong> – Organizes data using <code>.sort_values()</code> or <code>.sort_index()</code>. Used to rank or order records.</li>
#   <li><strong>Subsetting Columns</strong> – Select specific columns using <code>df["col"]</code> or <code>df[["col1","col2"]]</code>. Used to choose features.</li>
#   <li><strong>Subsetting Rows</strong> – Filter rows using conditions like <code>df[df["col"] > value]</code>. Used to select specific records.</li>
#   <li><strong>Combined Selection</strong> – Use <code>.loc[]</code> or <code>.iloc[]</code> to select rows and columns together.</li>
# </ul>

# %%
data = {
    "Day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "Steps": [7000, 8500, 9000, 10000, 7500, 8000, 6700],
    "Calories": [2200, 2100, 2300, 2500, 2000, 2400, 1900]
}
df_sorted=df.sort_values(by="Steps")
print("after sorting in aceding by Steps")
print(df_sorted)
#sorting in deceding orders
df_sorted_dec=df.sort_values(by="Steps",ascending=False)
print("After sorting in decending order")
print(df_sorted_dec)

#subneting  means selecting  by columns  oe  or more columns returns  series
df_sebneted=df[["Day","Calories"]]
print("After selecting  day and calories only")
print(df_sebneted)
#subneting  by rows   

df_high_steeps=df[df["Steps"]>7500]
#this nesting  array is inner to  returen the boolens  where  the conditios  ans  true or false  whre is the outer is to  returns  the  filterig data

print("After selecting  highest steps  by  row")
print(df_high_steeps)
#subneting  by multple condition
df_mul_subnet=df[(df["Steps"]>8000) & (df["Calories"]<2500)]
print("after subneting  by multple")
print(df_mul_subnet)
#finltering  some  rowsn usig isin()
weekend=df["Day"].isin(["Saturday","Sunday"])
print("Weekend of week")
print(weekend)
# Out:
# after sorting in aceding by Steps
#          Day  Steps  Calories  Sum_Steps  Calories_per_1000 Activity_Level
# 6     Sunday   6700      1900      56700         283.582090            Low
# 0     Monday   7000      2200      56700         314.285714            Low
# 4     Friday   7500      2000      56700         266.666667         Active
# 5   Saturday   8000      2400      56700         300.000000         Active
# 1    Tuesday   8500      2100      56700         247.058824         Active
# 2  Wednesday   9000      2300      56700         255.555556    Very Active
# 3   Thursday  10000      2500      56700         250.000000    Very Active
# After sorting in decending order
#          Day  Steps  Calories  Sum_Steps  Calories_per_1000 Activity_Level
# 3   Thursday  10000      2500      56700         250.000000    Very Active
# 2  Wednesday   9000      2300      56700         255.555556    Very Active
# 1    Tuesday   8500      2100      56700         247.058824         Active
# ...

# %% [markdown]
# <h2>Step 5: Adding New Columns</h2>
#
# <h5>Adding new columns in a pandas DataFrame is used to create new features from existing data. This is important in data analysis and AI preprocessing.</h5>
#
# <ul>
#   <li><strong>Direct Assignment</strong> – Create a new column using calculations from existing columns. Used for feature engineering.</li>
#   <li><strong>Conditional Columns</strong> – Create True/False columns based on conditions. Used for classification or filtering.</li>
#   <li><strong>Using Functions (.apply)</strong> – Apply custom logic to create categorical or derived features.</li>
#   <li><strong>Vectorized Operations</strong> – Perform operations on entire columns without loops for better performance.</li>
# </ul>

# %%
data = {
    "Day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "Steps": [7000, 8500, 9000, 10000, 7500, 8000, 6700],
    "Calories": [2200, 2100, 2300, 2500, 2000, 2400, 1900]
}

df = pd.DataFrame(data)
print(df)
df["Sum_Steps"]=df["Steps"].sum()
print("After new column is added")
print(df)
df["Calories_per_1000"]=df["Calories"]/(df["Steps"]/1000)
print("After adding using multple columns")
print(df)
#implemetnign using  .apply() functios     to adds costomanies columns
def activity_level(steps):
    if steps>=9000:
        return "Very Active"
    elif steps>=7500:
        return "Active"
    else:
        return "Low"
df["Activity_Level"]=df["Steps"].apply(activity_level)    
print("after applying using apply  function ")
print(df)
# Out:
#          Day  Steps  Calories
# 0     Monday   7000      2200
# 1    Tuesday   8500      2100
# 2  Wednesday   9000      2300
# 3   Thursday  10000      2500
# 4     Friday   7500      2000
# 5   Saturday   8000      2400
# 6     Sunday   6700      1900
# After new column is added
#          Day  Steps  Calories  Sum_Steps
# 0     Monday   7000      2200      56700
# 1    Tuesday   8500      2100      56700
# 2  Wednesday   9000      2300      56700
# 3   Thursday  10000      2500      56700
# 4     Friday   7500      2000      56700
# 5   Saturday   8000      2400      56700
# 6     Sunday   6700      1900      56700
# After adding using multple columns
#          Day  Steps  Calories  Sum_Steps  Calories_per_1000
# 0     Monday   7000      2200      56700         314.285714
# 1    Tuesday   8500      2100      56700         247.058824
# 2  Wednesday   9000      2300      56700         255.555556
# 3   Thursday  10000      2500      56700         250.000000
# ...

# %% [markdown]
# <h2>Step 6: Combo Attack and .assign()</h2>
#
# <h5>
# Combo Attack means using multiple DataFrame operations together
# to create new features and prepare data in one logical flow.
# It is used when transforming raw data into useful data for analysis or ML.
# </h5>
#
# <h5>
# Normal Combo Attack modifies the original DataFrame directly
# by adding new columns using df["new_column"] = expression.
# It is simple and good for quick transformations.
# </h5>
#
# <h5>
# .assign() is a pandas method used to add new columns
# without changing the original DataFrame.
# It returns a new DataFrame and is useful for clean and professional pipelines.
# </h5>
#
# <ul>
#   <li><strong>Combo Attack</strong> – Adds multiple columns step by step and modifies the original data.</li>
#   <li><strong>.assign()</strong> – Adds multiple columns in one statement and keeps original data safe.</li>
#   <li><strong>When to use Combo Attack</strong> – Small projects, quick analysis, simple scripts.</li>
#   <li><strong>When to use .assign()</strong> – Clean code, ML preprocessing, professional workflows.</li>
# </ul>

# %%
data1 = {
    "Day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "Steps": [7000, 8500, 9000, 10000, 7500, 8000, 6700],
    "Calories": [2200, 2100, 2300, 2500, 2000, 2400, 1900]
}

df = pd.DataFrame(data1)
df.index=[1,2,3,4,5,6,7]
print("Original Data")
print(df)
print("--------------------------------------------------------------")
print("after updation")
#this compo attack is  implemetig  defferent pandas oparation  togethere
df["Steps_Thousands"]=df["Steps"]/1000
df["Activity_Level"]=df["Steps"].apply(lambda x:"V. Active"if x>=9000 else "Active" if x>=7500 else "Low")
print(df)
#but this is implemete in  veiw  that means  it share the memory and  this is affectes the origninal data  to solves this problem it recommended to implemte using assign
data2 = {
    "Day": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "Steps": [7000, 8500, 9000, 10000, 7500, 8000, 6700],
    "Calories": [2200, 2100, 2300, 2500, 2000, 2400, 1900]
}
df2=pd.DataFrame(data2)
print("===================================================================================")
print("Original Data")
print(df2)
print("Data manuplation using assing")
new_df=df2.assign(
    Steps_Normalized=df2["Steps"]/df2["Steps"].max(),
    Comulative_Steps=df2["Steps"].cumsum(),
    Step_Ranks=df2["Steps"].rank(ascending=False),
    Calories_Categories=df2["Calories"].apply(lambda x: "Highest" if x>=2400 else "High" if x>=2200 else "Medium" if x>=2000 else "Low"),
    Steps_Percentage=df2["Steps"]/df2["Steps"].sum()
)
print(new_df)
print("-------------------------------------------------------------------")
print("original data after manuplation")
print(df2)
# Out:
# Original Data
#          Day  Steps  Calories
# 1     Monday   7000      2200
# 2    Tuesday   8500      2100
# 3  Wednesday   9000      2300
# 4   Thursday  10000      2500
# 5     Friday   7500      2000
# 6   Saturday   8000      2400
# 7     Sunday   6700      1900
# --------------------------------------------------------------
# after updation
#          Day  Steps  Calories  Steps_Thousands Activity_Level
# 1     Monday   7000      2200              7.0            Low
# 2    Tuesday   8500      2100              8.5         Active
# 3  Wednesday   9000      2300              9.0      V. Active
# 4   Thursday  10000      2500             10.0      V. Active
# 5     Friday   7500      2000              7.5         Active
# 6   Saturday   8000      2400              8.0         Active
# 7     Sunday   6700      1900              6.7            Low
# ...
# Original Data
#          Day  Steps  Calories
# 0     Monday   7000      2200
# 1    Tuesday   8500      2100
# ...

# %% [markdown]
# <h2>Aggregating DataFrames</h2>
#
# <h5>
# Aggregation means summarizing data to extract insights.
# It is widely used in data analysis, reporting, and AI preprocessing.
# </h5>
#
# <h5>Commonly used operations in real-world projects:</h5>
#
# <ul>
#   <li><strong>Mean / Median:</strong> Average or middle values of numeric columns.</li>
#   <li><strong>Sum:</strong> Total values, e.g., total steps or calories.</li>
#   <li><strong>Min / Max:</strong> Find lowest and highest values (outliers, top performers).</li>
#   <li><strong>Count:</strong> Count rows, non-missing values, or category occurrences.</li>
#   <li><strong>Cumulative statistics:</strong> Running totals or trends over time.</li>
#   <li><strong>Grouped summary (.groupby):</strong> Aggregate data by categories like day, activity level, or type.</li>
#   <li><strong>Pivot tables:</strong> Summarize data across multiple dimensions for reports or ML features.</li>
# </ul>
#
# <h5>Next steps:</h5>
# <p>We will start with the **most common numeric aggregations** (mean, median, sum, min, max) and show examples using your fitness dataset.</p>

# %%
import pandas  as pd
data={
    "store":["A","B","C","D","E","F"],
    "product":["X","Y","Z","X","Y","Z"],
    "quantity":[10,15,8,12,25,5],
    "revenue":[100,150,80,120,250,50]
}
df=pd.DataFrame(data)
df.index=[1,2,3,4,5,6]
print(df)
print("Results of Stats summary")
print("--------------------------------------------------------")
print("countes non missing values per column")
print(df.count())
print("min revenue and qty: ",df[["quantity","revenue"]].min())
print("Max revenue and qty: ",df[["quantity","revenue"]].max())
df["cum_rev"]=df["revenue"].cumsum()
print("after communaltive revenu is added")
print(df)
print("----------------------------------------------")
print("Group by opration  to categories based on their columns")
products=df.groupby("product")
print(products.groups)
#usage of gropu  by for  different   data manuplanstion
results=df.groupby("product")["revenue"].sum()
print(results)
#this  is used to in the  real  world  to impltes  their summery  by categories
qty=df.groupby("product")["quantity"].sum()
print("the products  qunatity per products type:")
print(qty)


#agg  this is imprtants this is importants  to apply multple opration at a time
revenue_status=df.groupby("product")["revenue"].agg(["sum","mean","max","min"])
print("after aggregating with agg")
print(revenue_status)
# Out:
#   store product  quantity  revenue
# 1     A       X        10      100
# 2     B       Y        15      150
# 3     C       Z         8       80
# 4     D       X        12      120
# 5     E       Y        25      250
# 6     F       Z         5       50
# Results of Stats summary
# --------------------------------------------------------
# countes non missing values per column
# store       6
# product     6
# quantity    6
# revenue     6
# dtype: int64
# min revenue and qty:  quantity     5
# revenue     50
# dtype: int64
# Max revenue and qty:  quantity     25
# revenue     250
# dtype: int64
# after communaltive revenu is added
#   store product  quantity  revenue  cum_rev
# 1     A       X        10      100      100
# 2     B       Y        15      150      250
# 3     C       Z         8       80      330
# 4     D       X        12      120      450
# 5     E       Y        25      250      700
# 6     F       Z         5       50      750
# ...

# %% [markdown]
# <h2>Removing Duplicate Rows (drop_duplicates)</h2>
#
# <h5>
# Removing duplicates means cleaning the dataset by eliminating repeated rows or repeated
# combinations of values. This is a very common step in data preprocessing because
# real-world datasets often contain duplicate records due to data entry errors,
# system logging duplication, or repeated imports.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>Duplicate rows:</strong> Rows that contain the same values in selected columns.</li>
#   <li><strong>subset parameter:</strong> Specifies which columns should be checked for duplicates.</li>
#   <li><strong>Data cleaning:</strong> Removing duplicates helps ensure accurate analysis and reporting.</li>
# </ul>
#
# <h5>How it works:</h5>
# <p>
# Pandas scans the specified columns and keeps the first occurrence of each unique
# combination while removing the rest.
# </p>
#
# <h5>Sample code:</h5>
#
# <pre>
# import pandas as pd
#
# sales = pd.DataFrame({
#     "store": ["A","A","B","B"],
#     "type": ["Super","Super","Discount","Discount"],
#     "department": [1,1,2,3]
# })
#
# store_types = sales.drop_duplicates(subset=["store","type"])
# print(store_types)
# </pre>
#
#
# <h2>Filtering Rows (Boolean Indexing)</h2>
#
# <h5>
# Filtering rows means selecting only the rows that satisfy a specific condition.
# This is one of the most frequently used operations in data analysis because
# analysts often need to focus on specific subsets of the data.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>Boolean condition:</strong> A condition that evaluates to True or False.</li>
#   <li><strong>Row selection:</strong> Rows where the condition is True are returned.</li>
#   <li><strong>Data exploration:</strong> Helps analyze specific segments of the dataset.</li>
# </ul>
#
# <h5>How it works:</h5>
# <p>
# Pandas evaluates the condition for each row. Rows that return True are included
# in the result while rows returning False are excluded.
# </p>
#
# <h5>Sample code:</h5>
#
# <pre>
# sales = pd.DataFrame({
#     "store": ["A","B","C","D"],
#     "is_holiday": [False, True, False, True],
#     "weekly_sales": [20000,25000,18000,30000]
# })
#
# holiday_sales = sales[sales["is_holiday"]]
# print(holiday_sales)
# </pre>
#
#
# <h2>Selecting Columns</h2>
#
# <h5>
# Selecting columns means retrieving specific columns from a DataFrame.
# This is useful when you only need certain information for analysis,
# visualization, or machine learning features.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>Column access:</strong> Columns are accessed using square brackets.</li>
#   <li><strong>Series output:</strong> Selecting one column returns a Pandas Series.</li>
#   <li><strong>Data focus:</strong> Helps reduce unnecessary data when performing operations.</li>
# </ul>
#
# <h5>How it works:</h5>
# <p>
# Pandas locates the column label and returns all values belonging to that column.
# </p>
#
# <h5>Sample code:</h5>
#
#
# <h2>Filtering and Removing Duplicate Dates</h2>
#
# <h5>
# Sometimes datasets contain multiple rows with the same date because
# different entities (such as stores or users) report data on the same day.
# In such cases, we may want to extract only the unique dates.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>Row filtering:</strong> Selecting rows that meet a condition.</li>
#   <li><strong>Duplicate removal:</strong> Ensuring each date appears only once.</li>
#   <li><strong>Data summarization:</strong> Useful for identifying unique events or time points.</li>
# </ul>
#
#
#
# <h5>Sample code:</h5>

# %%
sales=pd.DataFrame({
    "store":["A","A","B","B"],
    "type":["super","super","discount","discount"],
    "department":[1,1,2,3]
})
print("oringinal data")
print(sales)
store_type=sales.drop_duplicates(subset=["store","type"])
print("unique stores-type combination")
print(store_type)
# Out:
# oringinal data
#   store      type  department
# 0     A     super           1
# 1     A     super           1
# 2     B  discount           2
# 3     B  discount           3
# unique stores-type combination
#   store      type  department
# 0     A     super           1
# 2     B  discount           2

# %% [markdown]
# <h2>Pivot Tables</h2>
#
# <h5>
# A pivot table is a data analysis technique used to summarize, reorganize,
# and explore datasets by grouping values into meaningful categories.
# It helps transform raw, detailed data into a structured summary
# that is easier to read, compare, and analyze.
# Pivot tables are widely used in data analysis, reporting, and data preprocessing.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>Rows (Index):</strong> The main categories used to organize the data vertically.</li>
#   <li><strong>Columns:</strong> Additional categories used to organize the data horizontally.</li>
#   <li><strong>Values:</strong> The numeric data that will be summarized or aggregated.</li>
#   <li><strong>Aggregation:</strong> The operation used to summarize values, such as sum, mean, count, min, or max.</li>
# </ul>
#
# <h5>When pivot tables are used:</h5>
#
# <ul>
#   <li><strong>Data summarization:</strong> When large datasets need to be condensed into a simpler form.</li>
#   <li><strong>Category-based analysis:</strong> When data must be analyzed across different groups or categories.</li>
#   <li><strong>Reporting and dashboards:</strong> When generating structured summaries for analysis or presentation.</li>
#   <li><strong>Data transformation:</strong> When converting long datasets into structured table formats.</li>
# </ul>
#
# <h5>Why pivot tables are important:</h5>
#
# <ul>
#   <li><strong>Simplifies complex datasets:</strong> Large and detailed datasets become easier to interpret.</li>
#   <li><strong>Reveals patterns:</strong> Helps identify trends and relationships between variables.</li>
#   <li><strong>Improves data exploration:</strong> Allows analysts to quickly reorganize data in multiple ways.</li>
#   <li><strong>Supports decision-making:</strong> Structured summaries make insights clearer and faster to obtain.</li>
# </ul>
#
# <h5>How pivot tables solve problems:</h5>
#
# <ul>
#   <li><strong>Organizing data:</strong> Rearranges raw data into structured summaries.</li>
#   <li><strong>Reducing redundancy:</strong> Combines repeated records into aggregated values.</li>
#   <li><strong>Improving readability:</strong> Makes large datasets easier to analyze and interpret.</li>
# </ul>
#
# <br>
#
# <h5>
# Pivot tables are one of the most powerful tools in data analysis
# because they allow data to be summarized, reorganized, and analyzed
# from multiple perspectives with minimal code.
# </h5>

# %%
import pandas as pd
import pandas as pd

sales = pd.DataFrame({
    "store": ["A","A","B","B","C","C"],
    "product": ["Phone","Laptop","Phone","Laptop","Phone","Laptop"],
    "revenue": [1000,2000,1500,2500,1200,2100]
})

print(sales)

#reorganizing using the pivot table

pivot=pd.pivot_table(
    sales,
    index="store",
    columns="product",
    values="revenue"
)

print("--------------------------------------")
print(pivot)

#pivot table with aggregation
pivot_sum=pd.pivot_table(
    sales,
    index="store",
    columns="product",
    values="revenue",
    aggfunc="sum"
)
print("-------------------------------------")
print(pivot_sum)

pivot_mean = pd.pivot_table(
    sales,
    index="store",
    columns="product",
    values="revenue",
    aggfunc="mean"
)

print(pivot_mean)
# Out:
#   store product  revenue
# 0     A   Phone     1000
# 1     A  Laptop     2000
# 2     B   Phone     1500
# 3     B  Laptop     2500
# 4     C   Phone     1200
# 5     C  Laptop     2100
# --------------------------------------
# product  Laptop   Phone
# store
# A        2000.0  1000.0
# B        2500.0  1500.0
# C        2100.0  1200.0
# -------------------------------------
# product  Laptop  Phone
# store
# A          2000   1000
# B          2500   1500
# C          2100   1200
# product  Laptop   Phone
# store
# A        2000.0  1000.0
# B        2500.0  1500.0
# C        2100.0  1200.0

# %% [markdown]
# <h2>List Slicing, loc, and iloc</h2>
#
# <h5>
# In data analysis, selecting parts of your dataset is crucial.
# Python provides <strong>list slicing</strong> for sequences,
# while pandas provides <strong>loc</strong> and <strong>iloc</strong>
# for DataFrame selection.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
#   <li><strong>List Slicing:</strong> Extracts elements from a Python list or array using <code>[start:stop:step]</code>.</li>
#   <li><strong>loc:</strong> Label-based indexing in pandas, selects rows/columns by names.</li>
#   <li><strong>iloc:</strong> Position-based indexing in pandas, selects rows/columns by integer positions.</li>
# </ul>
#
# <h5>When to use them:</h5>
#
# <ul>
#   <li><strong>List slicing:</strong> When working with Python lists, tuples, or arrays.</li>
#   <li><strong>loc:</strong> When row/column labels are meaningful, e.g., dates, IDs, categories.</li>
#   <li><strong>iloc:</strong> When row/column positions are more important than labels, e.g., ML pipelines, numeric analysis.</li>
# </ul>
#
# <h5>Why they are important:</h5>
#
# <ul>
#   <li><strong>List slicing:</strong> Quickly get a subset of data without loops.</li>
#   <li><strong>loc:</strong> Safe selection using meaningful labels; avoids mistakes if index is non-numeric or unsorted.</li>
#   <li><strong>iloc:</strong> Quick numeric selection; works like Python slicing but on DataFrames.</li>
# </ul>
#
# <h5>Problems they solve:</h5>
#
# <ul>
#   <li><strong>List slicing:</strong> Avoids writing manual loops for subset extraction.</li>
#   <li><strong>loc:</strong> Select specific rows and columns by label; maintain label alignment.</li>
#   <li><strong>iloc:</strong> Select specific rows and columns by position; useful when labels are unknown.</li>
# </ul>
#
# <h5>Quick tip:</h5>
#
# <ul>
#   <li><strong>Python slicing:</strong> [start:stop:step] → exclusive stop.</li>
#   <li><strong>iloc:</strong> [start:stop] → like list slicing, exclusive stop.</li>
#   <li><strong>loc:</strong> [label1:label2] → inclusive stop.</li>
# </ul>

# %%
df = pd.DataFrame({
    "store": ["A","B","C","D"],
    "revenue": [1000, 2000, 1500, 2500]
},index=["r1","r2","r3","r4"])
print(df)
#python lists
revenues = df["revenue"].tolist()
print("\nList slicing [1:3]:")
print(revenues[1:3])
print("\nloc: select multiple rows and columns by labels:")
print(df.loc["r1":"r2"])
print("\niloc: select first three rows and both columns:")
print(df.iloc[0:3,0:2])
# Out:
#    store  revenue
# r1     A     1000
# r2     B     2000
# r3     C     1500
# r4     D     2500
#
# List slicing [1:3]:
# [2000, 1500]
#
# loc: select multiple rows and columns by labels:
#    store  revenue
# r1     A     1000
# r2     B     2000
#
# iloc: select first three rows and both columns:
#    store  revenue
# r1     A     1000
# r2     B     2000
# r3     C     1500

# %% [markdown]
# <h2>Reading CSV Files with Pandas</h2>
#
# <h5>
# Reading CSV (Comma-Separated Values) files is one of the most common ways to load
# real-world datasets into Python for analysis. CSV files are simple text files that
# store tabular data where columns are separated by commas (or other delimiters).
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
# <li><strong>CSV file:</strong> A text file storing structured tabular data with rows and columns.</li>
# <li><strong>Pandas function:</strong> <code>pd.read_csv()</code> is used to read CSV files into a DataFrame.</li>
# <li><strong>DataFrame:</strong> The pandas object used for analysis after reading the CSV.</li>
# <li><strong>File path:</strong> The location of your CSV file on disk.</li>
# </ul>
#
# <h5>When we use reading CSV files:</h5>
#
# <ul>
# <li>Loading datasets for analysis or machine learning projects.</li>
# <li>Reading exported data from databases, Excel, or other systems.</li>
# <li>Working with real-world datasets shared online (Kaggle, UCI, government data).</li>
# </ul>
#
# <h5>Why reading CSV files is important:</h5>
#
# <ul>
# <li>CSV is the most common format for datasets in data science and analytics.</li>
# <li>Enables quick import of data into pandas for cleaning, manipulation, and visualization.</li>
# <li>Allows reproducible workflows by reading the same data in scripts or notebooks.</li>
# <li>Supports handling large datasets efficiently.</li>
# </ul>
#
# <h5>Problems it solves:</h5>
#
# <ul>
# <li>Manual data entry errors – you can directly load structured data.</li>
# <li>Converting raw data into a DataFrame for analysis.</li>
# <li>Reading datasets from external sources without retyping them.</li>
# <li>Loading multiple datasets consistently for aggregation or merging.</li>
# </ul>
#
# <h5>Key Pandas Parameters for <code>pd.read_csv()</code>:</h5>
#
# <ul>
# <li><strong>filepath_or_buffer:</strong> Path to the CSV file.</li>
# <li><strong>sep:</strong> Separator character (default is comma).</li>
# <li><strong>header:</strong> Row number to use as column names (default 0).</li>
# <li><strong>index_col:</strong> Column to use as row index (optional).</li>
# <li><strong>usecols:</strong> Select specific columns.</li>
# <li><strong>na_values:</strong> Specify strings to consider as missing values.</li>
# <li><strong>parse_dates:</strong> Parse columns as datetime.</li>
# </ul>

# %%
import pandas as pd 
df_csv = pd.read_csv("countries_data.csv",index_col="Country")
print(df_csv)


df_json = pd.read_json("countries_data.json")
df=pd.read_csv("data/products_dataset.csv")
print(df_json)
#selection  by column
print("-------------seletion operation ")

print(df_csv[["Area_km2","Capital"]])

print("selection by row")
print(df_csv.loc["India"].to_string)
print(df_csv.loc["Ethiopia":"Japan":2])
# country_name=input("Enter countries name: ").capitalize()
# try:
#       print(df_csv.loc[country_name])
      
# except KeyError:
#       print(f"{country_name} not found")
# # print(df)   
print(df)
print(df.columns)
# Out:
#               Capital      Continent  Population  Area_km2  GDP_Billion_USD  \
# Country
# Ethiopia  Addis Ababa         Africa   123379924   1104300            156.1
# Kenya         Nairobi         Africa    55100586    580367            113.4
# Germany        Berlin         Europe    83240525    357022           4210.0
# Canada         Ottawa  North America    38929902   9984670           2140.0
# Japan           Tokyo           Asia   125836021    377975           4230.0
# Brazil       Brasilia  South America   203062512   8515767           2130.0
# India       New Delhi           Asia  1428627663   3287263           3730.0
#
#          Official_Language
# Country
# Ethiopia           Amharic
# Kenya              Swahili
# Germany             German
# Canada      English/French
# Japan             Japanese
# Brazil          Portuguese
# India                Hindi
#                                            countries
# 0  {'name': 'Ethiopia', 'capital': 'Addis Ababa',...
# ...

# %%
print(df.describe())
#renaming clumn
df.rename(columns={"product_name":"pro_name"},inplace=True)
df.rename(columns={"products_name":"pro_id"},inplace=True)
print(df.columns)
# Out:
#        product_id        price      rating  popularity    discount       stock
# count  100.000000   100.000000  100.000000  100.000000  100.000000  100.000000
# mean    50.500000   120.430000    4.278000   75.180000   13.100000   89.580000
# std     29.011492   204.020164    0.193626    8.681084    4.205576   52.988503
# min      1.000000     4.000000    3.900000   58.000000    6.000000   18.000000
# 25%     25.750000    21.500000    4.100000   68.750000   10.000000   50.000000
# 50%     50.500000    47.500000    4.300000   75.000000   12.000000   75.000000
# 75%     75.250000   120.000000    4.400000   82.000000   15.750000  116.250000
# max    100.000000  1100.000000    4.700000   92.000000   22.000000  230.000000
# Index(['product_id', 'pro_name', 'category', 'price', 'rating', 'popularity',
#        'discount', 'stock'],
#       dtype='str')

# %% [markdown]
# <h2>Data Visualization</h2>
#
# <h5>
# Data visualization is the process of representing data graphically using charts and plots.
# It helps analysts and developers understand patterns, trends, comparisons, and relationships
# in data more quickly than reading raw numbers or tables.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
# <li><strong>Visualization:</strong> Transforming numerical or categorical data into graphical representations.</li>
# <li><strong>Charts and plots:</strong> Visual tools like line charts, bar charts, scatter plots, histograms, and box plots.</li>
# <li><strong>Libraries:</strong> Python tools such as Matplotlib and Seaborn used to create visualizations.</li>
# </ul>
#
# <h5>When we use data visualization:</h5>
#
# <ul>
# <li>To explore and understand datasets during analysis.</li>
# <li>To identify trends, patterns, and outliers in data.</li>
# <li>To compare categories or variables clearly.</li>
# <li>To communicate insights in reports, dashboards, or presentations.</li>
# </ul>
#
# <h5>Why data visualization is important:</h5>
#
# <ul>
# <li>Humans understand patterns faster through visuals than raw numbers.</li>
# <li>It simplifies complex datasets and highlights key insights.</li>
# <li>It improves decision-making in business, science, and engineering.</li>
# <li>It helps communicate results effectively to stakeholders.</li>
# </ul>
#
# <h5>Problems it solves:</h5>
#
# <ul>
# <li>Difficulty understanding large numerical datasets.</li>
# <li>Hidden patterns or relationships in raw tables.</li>
# <li>Poor communication of analytical results.</li>
# <li>Challenges comparing multiple variables or categories.</li>
# </ul>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May"]
revenue = [1000,1200,1500,1300,1700]
plt.plot(months,revenue)
plt.xlabel("months")
plt.ylabel("revenue")
plt.title("Monthly Revenue Trend")
plt.show()

# %%
stores = ["A","B","C","D"]
revenue = [1000,2000,1500,2500]
plt.bar(stores,revenue)
plt.xlabel("Store")
plt.ylabel("Revenue")
plt.title("Revenue by Store")
plt.show()

# %%
advertising = [10,20,30,40,50]
sales = [100,150,200,230,300]
plt.scatter(advertising,sales)
plt.title("Advertizing vs Sales")
plt.xlabel("Advertising Budget")
plt.ylabel("Sales")
plt.show()

# %%
ages = [20,21,22,22,23,24,25,25,25,26,27,28]
plt.hist(ages)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()
print("box plot")
plt.boxplot(ages)
plt.title("Age Distribution")

plt.show()
# Out:
# box plot

# %% [markdown]
# <h2>Data Cleaning with Pandas</h2>
#
# <h5>
# Data cleaning is the process of preparing raw data for analysis by fixing
# errors, handling missing values, removing duplicates, and transforming data
# into a consistent format. In real-world data science and analytics projects,
# a large portion of the work involves cleaning and preparing data before
# analysis or visualization.
# </h5>
#
# <h5>What you need to understand:</h5>
#
# <ul>
# <li><strong>Raw data:</strong> Data collected from real sources that may contain errors, missing values, or inconsistencies.</li>
# <li><strong>Data cleaning:</strong> The process of detecting and correcting problems in datasets.</li>
# <li><strong>Pandas tools:</strong> Functions and methods that help identify and fix issues in data.</li>
# </ul>
#
# <h5>When we use data cleaning:</h5>
#
# <ul>
# <li>Before performing data analysis or visualization.</li>
# <li>Before training machine learning models.</li>
# <li>When datasets contain missing values, duplicates, or inconsistent formats.</li>
# <li>When combining or merging multiple datasets.</li>
# </ul>
#
# <h5>Why data cleaning is important:</h5>
#
# <ul>
# <li>Ensures accurate analysis and reliable results.</li>
# <li>Prevents errors in calculations and models.</li>
# <li>Improves data quality and consistency.</li>
# <li>Makes datasets easier to analyze and visualize.</li>
# </ul>
#
# <h5>Problems it solves:</h5>
#
# <ul>
# <li>Missing values in datasets.</li>
# <li>Duplicate rows or repeated records.</li>
# <li>Incorrect or inconsistent data formats.</li>
# <li>Irrelevant or unnecessary data entries.</li>
# </ul>
#
# <h5>Key data-cleaning skills in pandas:</h5>
#
# <ul>
# <li><strong>Detecting missing values:</strong> Identify empty or null values in datasets.</li>
# <li><strong>Handling missing values:</strong> Remove or replace missing data.</li>
# <li><strong>Removing duplicates:</strong> Detect and drop repeated rows.</li>
# <li><strong>Filtering data:</strong> Select only relevant rows for analysis.</li>
# <li><strong>Renaming columns:</strong> Standardize column names for clarity.</li>
# <li><strong>Changing data types:</strong> Convert values to correct formats such as integers, floats, or dates.</li>
# <li><strong>Sorting and organizing data:</strong> Arrange datasets to improve readability and analysis.</li>
# </ul>

# %%
import pandas as pd
df=pd.DataFrame(
    {
    "store": ["A","B","C","C"],
    "revenue": [1000, None, 1500, 1500],
    "employees": [5,6,None,6]
}
    
)
print(df)
print(df.isna())
print("how many vlues are  missed: ",df.isna().sum())
#handling missing values
df["revenue"]=df["revenue"].fillna(0)
df["employees"]=df["employees"].fillna(1)
print("after  filling the missing values: ")
print(df)
#filling with mean values
df["employees"]=df["employees"].fillna(df["employees"].mean())
print("after filling with mean: ")
print(df)

#remving duplicated  datas and checking the ducplicate
print(df.duplicated())
# Out:
#   store  revenue  employees
# 0     A   1000.0        5.0
# 1     B      NaN        6.0
# 2     C   1500.0        NaN
# 3     C   1500.0        6.0
#    store  revenue  employees
# 0  False    False      False
# 1  False     True      False
# 2  False    False       True
# 3  False    False      False
# how many vlues are  missed:  store        0
# revenue      1
# employees    1
# dtype: int64
# after  filling the missing values:
#   store  revenue  employees
# 0     A   1000.0        5.0
# 1     B      0.0        6.0
# 2     C   1500.0        1.0
# 3     C   1500.0        6.0
# after filling with mean:
#   store  revenue  employees
# 0     A   1000.0        5.0
# 1     B      0.0        6.0
# 2     C   1500.0        1.0
# 3     C   1500.0        6.0
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
